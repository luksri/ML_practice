# %%
import sklearn
import pandas as pd
import numpy as np
import os
from sklearn import preprocessing
from sklearn import impute
from sklearn import pipeline
from sklearn import compose
from sklearn import model_selection
from sklearn import tree, neighbors

# %%
dir = '../'
train_data = pd.read_csv(os.path.join(dir, 'train.csv'))
# train_data = train_data.iloc[:1000]
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159256 entries, 0 to 159255
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   159256 non-null  int64
#  1   age                  159256 non-null  int64
#  2   height(cm)           159256 non-null  int64
#  3   weight(kg)           159256 non-null  int64
#  4   waist(cm)            159256 non-null  float64
#  5   eyesight(left)       159256 non-null  float64
#  6   eyesight(right)      159256 non-null  float64
#  7   hearing(left)        159256 non-null  int64
#  8   hearing(right)       159256 non-null  int64
#  9   systolic             159256 non-null  int64
#  10  relaxation           159256 non-null  int64
#  11  fasting blood sugar  159256 non-null  int64
#  12  Cholesterol          159256 non-null  int64
#  13  triglyceride         159256 non-null  int64
#  14  HDL                  159256 non-null  int64
#  15  LDL                  159256 non-null  int64
#  16  hemoglobin           159256 non-null  float64
#  17  Urine protein        159256 non-null  int64
#  18  serum creatinine     159256 non-null  float64
#  19  AST                  159256 non-null  int64
#  20  ALT                  159256 non-null  int64
#  21  Gtp                  159256 non-null  int64
#  22  dental caries        159256 non-null  int64
#  23  smoking              159256 non-null  int64
# dtypes: float64(5), int64(19)
# memory usage: 29.2 MB

# %%
train_data.head(100)
# Out:
#     id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0    0   55         165          60       81.0             0.5
# 1    1   70         165          65       89.0             0.6
# 2    2   20         170          75       81.0             0.4
# 3    3   35         180          95      105.0             1.5
# 4    4   30         165          60       80.5             1.5
# ..  ..  ...         ...         ...        ...             ...
# 95  95   60         160          75       95.2             1.2
# 96  96   60         160          50       67.2             0.9
# 97  97   40         160          70       82.0             1.2
# 98  98   35         175          90       97.0             0.6
# 99  99   60         160          65       86.0             0.3
#
#     eyesight(right)  hearing(left)  hearing(right)  systolic  ...  HDL  LDL  \
# 0               0.6              1               1       135  ...   40   75
# 1               0.7              2               2       146  ...   57  126
# 2               0.5              1               1       118  ...   45   93
# 3               1.2              1               1       131  ...   38  102
# 4               1.0              1               1       121  ...   44   93
# ..              ...            ...             ...       ...  ...  ...  ...
# 95              1.0              1               1       124  ...   39   88
# 96              0.9              1               1       112  ...  100  102
# 97              1.2              1               1       128  ...   59  140
# 98              0.7              1               1       118  ...   47  148
# 99              0.7              2               2       116  ...   62   97
#
#     hemoglobin  Urine protein  serum creatinine  AST  ALT  Gtp  dental caries  \
# 0         16.5              1               1.0   22   25   27              0
# 1         16.2              1               1.1   27   23   37              1
# 2         17.4              1               0.8   27   31   53              0
# 3         15.9              1               1.0   20   27   30              1
# 4         15.4              1               0.8   19   13   17              0
# ..         ...            ...               ...  ...  ...  ...            ...
# 95        17.1              1               1.0   26   31   23              1
# 96        13.8              1               0.7   29   21   14              0
# 97        13.9              1               0.8   27   26   23              1
# 98        15.4              1               0.9   22   37   35              0
# 99        15.9              1               0.9   24   20   45              0
#
#     smoking
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1
# ..      ...
# 95        1
# 96        0
# 97        0
# 98        0
# 99        1
#
# [100 rows x 24 columns]

# %%
cont = ["hemoglobin", "height(cm)", "triglyceride", "HDL", "Gtp"]

stages = [('cont_imp',impute.SimpleImputer()),('scaler', preprocessing.StandardScaler()), ("knn", neighbors.KNeighborsClassifier(algorithm='brute'))]
pipe = pipeline.Pipeline(stages)
pipe
# Out:
# Pipeline(steps=[('cont_imp', SimpleImputer()), ('scaler', StandardScaler()),
#                 ('knn', KNeighborsClassifier(algorithm='brute'))])

# %%
### now set the fine tuning 
X_train = train_data
y_train = train_data['smoking']

pipe_grid = { 'cont_imp__strategy':['mean', 'median'], 'knn__n_neighbors':[2,3]}
cv = model_selection.KFold(10)
clf = model_selection.GridSearchCV(pipe, pipe_grid, cv=cv, scoring='accuracy',return_train_score=True)
try:
    clf.fit(X_train, y_train)
except Exception as e:
    print(e)
print(clf.best_params_)
print(clf.best_score_)
print(clf.best_index_)
print(clf.best_estimator_)

# %%
smoke_test = pd.read_csv(os.path.join(dir, "test.csv"))
# print(smoke_test.shape)
# print(smoke_test.head())
# print(smoke_test.info())



X_test = smoke_test[cont]
# print(X_test)
smoke_test['smoking'] = clf.predict(X_test)
smoke_test.head()


smoke_test.to_csv(os.path.join(dir, "submission1.csv"), columns=["id", "smoking"], index=False)
