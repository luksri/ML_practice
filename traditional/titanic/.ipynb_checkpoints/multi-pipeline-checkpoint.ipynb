# %%
import pandas as pd
import os
import sklearn
from sklearn import tree 
from sklearn import preprocessing
from sklearn import model_selection
from sklearn import impute
from sklearn import pipeline
from sklearn import compose
import numpy as np
sklearn.set_config(display="diagram")

# %%
dir = "C:/Users/pc/Downloads/ai-level1/titanic"
titanic_train = pd.read_csv(os.path.join(dir, "train.csv"))
titanic_train.shape
titanic_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
cont_features = ['SibSp', 'Parch', 'Age']
steps = [('cont_imp', impute.SimpleImputer()), ('scaler', preprocessing.StandardScaler())]
cont_pipe = pipeline.Pipeline(steps)
#cont_pipe.fit_transform(titanic_train[cont_features])
#cont_pipe
# Out:
# array([[ 0.43279337, -0.47367361, -0.5924806 ],
#        [ 0.43279337, -0.47367361,  0.63878901],
#        [-0.4745452 , -0.47367361, -0.2846632 ],
#        ...,
#        [ 0.43279337,  2.00893337,  0.        ],
#        [-0.4745452 , -0.47367361, -0.2846632 ],
#        [-0.4745452 , -0.47367361,  0.17706291]])

# %%
cat_features = ['Embarked', 'Sex', 'Pclass']
steps = [('cat_imp', impute.SimpleImputer(strategy="most_frequent")), ('enc', preprocessing.OrdinalEncoder(dtype=np.int32))]
cat_pipe = pipeline.Pipeline(steps)
#cat_pipe.fit_transform(titanic_train[cat_features])
#cat_pipe
# Out:
# array([[2, 1, 2],
#        [0, 0, 0],
#        [2, 0, 2],
#        ...,
#        [2, 0, 2],
#        [0, 1, 0],
#        [1, 1, 2]])

# %%
pre_pipe = compose.ColumnTransformer(
    [ ("categorical", cat_pipe, cat_features), ("numerical", cont_pipe, cont_features),  ]
)
#pre_pipe.fit_transform(titanic_train)
#pre_pipe
# Out:
# array([[ 2.        ,  1.        ,  2.        ,  0.43279337, -0.47367361,
#         -0.5924806 ],
#        [ 0.        ,  0.        ,  0.        ,  0.43279337, -0.47367361,
#          0.63878901],
#        [ 2.        ,  0.        ,  2.        , -0.4745452 , -0.47367361,
#         -0.2846632 ],
#        ...,
#        [ 2.        ,  0.        ,  2.        ,  0.43279337,  2.00893337,
#          0.        ],
#        [ 0.        ,  1.        ,  0.        , -0.4745452 , -0.47367361,
#         -0.2846632 ],
#        [ 1.        ,  1.        ,  2.        , -0.4745452 , -0.47367361,
#          0.17706291]])

# %%
pipe = pipeline.Pipeline(
    steps=[("pre", pre_pipe), ("dt", tree.DecisionTreeClassifier())]
)
pipe
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('cat_imp',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('enc',
#                                                                    OrdinalEncoder(dtype=<class 'numpy.int32'>))]),
#                                                   ['Embarked', 'Sex',
#                                                    'Pclass']),
#                                                  ('numerical',
#                                                   Pipeline(steps=[('cont_imp',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['SibSp', 'Parch', 'Age'])])),
#                 ('dt', DecisionTreeClassifier())])

# %%
X_train = titanic_train
y_train = titanic_train['Survived']
pipe_grid = { 'pre__numerical__cont_imp__strategy':['mean', 'median'], 'dt__max_depth':list(range(1, 10)), 'dt__min_samples_split':[2, 5, 10]}
cv = model_selection.KFold(10)
clf = model_selection.GridSearchCV(pipe, pipe_grid, cv=cv, scoring='accuracy',return_train_score=True)
clf.fit(X_train, y_train)
print(clf.best_params_)
print(clf.best_score_)
print(clf.best_index_)
print(clf.best_estimator_)
df = pd.DataFrame(clf.cv_results_)
columns = ['params', 'split0_test_score', 'split1_test_score', 'split9_test_score', 'mean_test_score']
print(df[columns])
# Out:
# {'dt__max_depth': 4, 'dt__min_samples_split': 10, 'pre__numerical__cont_imp__strategy': 'median'}
# 0.8283021223470662
# 23
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('cat_imp',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('enc',
#                                                                    OrdinalEncoder(dtype=<class 'numpy.int32'>))]),
#                                                   ['Embarked', 'Sex',
#                                                    'Pclass']),
#                                                  ('numerical',
#                                                   Pipeline(steps=[('cont_imp',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['SibSp', 'Parch', 'Age'])])),
#                 ('dt',
#                  DecisionTreeClassifier(max_depth=4, min_samples_split=10))])
#                                                params  split0_test_score  \
# 0   {'dt__max_depth': 1, 'dt__min_samples_split': ...           0.811111
# 1   {'dt__max_depth': 1, 'dt__min_samples_split': ...           0.811111
# 2   {'dt__max_depth': 1, 'dt__min_samples_split': ...           0.811111
# 3   {'dt__max_depth': 1, 'dt__min_samples_split': ...           0.811111
# 4   {'dt__max_depth': 1, 'dt__min_samples_split': ...           0.811111
# 5   {'dt__max_depth': 1, 'dt__min_samples_split': ...           0.811111
# 6   {'dt__max_depth': 2, 'dt__min_samples_split': ...           0.677778
# 7   {'dt__max_depth': 2, 'dt__min_samples_split': ...           0.677778
# 8   {'dt__max_depth': 2, 'dt__min_samples_split': ...           0.677778
# 9   {'dt__max_depth': 2, 'dt__min_samples_split': ...           0.677778
# 10  {'dt__max_depth': 2, 'dt__min_samples_split': ...           0.677778
# 11  {'dt__max_depth': 2, 'dt__min_samples_split': ...           0.677778
# 12  {'dt__max_depth': 3, 'dt__min_samples_split': ...           0.822222
# 13  {'dt__max_depth': 3, 'dt__min_samples_split': ...           0.811111
# 14  {'dt__max_depth': 3, 'dt__min_samples_split': ...           0.822222
# 15  {'dt__max_depth': 3, 'dt__min_samples_split': ...           0.811111
# 16  {'dt__max_depth': 3, 'dt__min_samples_split': ...           0.822222
# 17  {'dt__max_depth': 3, 'dt__min_samples_split': ...           0.811111
# 18  {'dt__max_depth': 4, 'dt__min_samples_split': ...           0.822222
# 19  {'dt__max_depth': 4, 'dt__min_samples_split': ...           0.811111
# 20  {'dt__max_depth': 4, 'dt__min_samples_split': ...           0.822222
# 21  {'dt__max_depth': 4, 'dt__min_samples_split': ...           0.811111
# 22  {'dt__max_depth': 4, 'dt__min_samples_split': ...           0.822222
# 23  {'dt__max_depth': 4, 'dt__min_samples_split': ...           0.811111
# 24  {'dt__max_depth': 5, 'dt__min_samples_split': ...           0.833333
# 25  {'dt__max_depth': 5, 'dt__min_samples_split': ...           0.833333
# 26  {'dt__max_depth': 5, 'dt__min_samples_split': ...           0.833333
# 27  {'dt__max_depth': 5, 'dt__min_samples_split': ...           0.822222
# 28  {'dt__max_depth': 5, 'dt__min_samples_split': ...           0.833333
# 29  {'dt__max_depth': 5, 'dt__min_samples_split': ...           0.822222
# 30  {'dt__max_depth': 6, 'dt__min_samples_split': ...           0.800000
# 31  {'dt__max_depth': 6, 'dt__min_samples_split': ...           0.788889
# 32  {'dt__max_depth': 6, 'dt__min_samples_split': ...           0.800000
# 33  {'dt__max_depth': 6, 'dt__min_samples_split': ...           0.788889
# 34  {'dt__max_depth': 6, 'dt__min_samples_split': ...           0.800000
# 35  {'dt__max_depth': 6, 'dt__min_samples_split': ...           0.788889
# 36  {'dt__max_depth': 7, 'dt__min_samples_split': ...           0.755556
# 37  {'dt__max_depth': 7, 'dt__min_samples_split': ...           0.733333
# 38  {'dt__max_depth': 7, 'dt__min_samples_split': ...           0.755556
# 39  {'dt__max_depth': 7, 'dt__min_samples_split': ...           0.722222
# 40  {'dt__max_depth': 7, 'dt__min_samples_split': ...           0.755556
# 41  {'dt__max_depth': 7, 'dt__min_samples_split': ...           0.722222
# 42  {'dt__max_depth': 8, 'dt__min_samples_split': ...           0.733333
# 43  {'dt__max_depth': 8, 'dt__min_samples_split': ...           0.733333
# 44  {'dt__max_depth': 8, 'dt__min_samples_split': ...           0.722222
# 45  {'dt__max_depth': 8, 'dt__min_samples_split': ...           0.711111
# 46  {'dt__max_depth': 8, 'dt__min_samples_split': ...           0.744444
# 47  {'dt__max_depth': 8, 'dt__min_samples_split': ...           0.733333
# 48  {'dt__max_depth': 9, 'dt__min_samples_split': ...           0.733333
# 49  {'dt__max_depth': 9, 'dt__min_samples_split': ...           0.733333
# 50  {'dt__max_depth': 9, 'dt__min_samples_split': ...           0.700000
# 51  {'dt__max_depth': 9, 'dt__min_samples_split': ...           0.677778
# 52  {'dt__max_depth': 9, 'dt__min_samples_split': ...           0.722222
# 53  {'dt__max_depth': 9, 'dt__min_samples_split': ...           0.722222
#
#     split1_test_score  split9_test_score  mean_test_score
# 0            0.820225           0.764045         0.786729
# 1            0.820225           0.764045         0.786729
# 2            0.820225           0.764045         0.786729
# 3            0.820225           0.764045         0.786729
# 4            0.820225           0.764045         0.786729
# 5            0.820225           0.764045         0.786729
# 6            0.797753           0.764045         0.766654
# 7            0.797753           0.764045         0.766654
# 8            0.797753           0.764045         0.766654
# 9            0.797753           0.764045         0.766654
# 10           0.797753           0.764045         0.766654
# 11           0.797753           0.764045         0.766654
# 12           0.842697           0.820225         0.817054
# 13           0.842697           0.820225         0.815943
# 14           0.842697           0.820225         0.817054
# 15           0.842697           0.820225         0.815943
# 16           0.842697           0.820225         0.817054
# 17           0.842697           0.820225         0.815943
# 18           0.842697           0.876404         0.827166
# 19           0.842697           0.876404         0.827179
# 20           0.842697           0.876404         0.826042
# 21           0.842697           0.876404         0.827179
# 22           0.842697           0.876404         0.827166
# 23           0.842697           0.876404         0.828302
# 24           0.831461           0.853933         0.815918
# 25           0.831461           0.831461         0.817041
# 26           0.831461           0.853933         0.817041
# 27           0.831461           0.831461         0.814806
# 28           0.831461           0.853933         0.817041
# 29           0.831461           0.831461         0.815930
# 30           0.865169           0.797753         0.811461
# 31           0.865169           0.820225         0.815968
# 32           0.865169           0.820225         0.814831
# 33           0.865169           0.820225         0.815968
# 34           0.865169           0.808989         0.814831
# 35           0.865169           0.831461         0.818215
# 36           0.820225           0.831461         0.800275
# 37           0.820225           0.808989         0.800300
# 38           0.808989           0.820225         0.800275
# 39           0.820225           0.786517         0.798065
# 40           0.842697           0.820225         0.803645
# 41           0.842697           0.797753         0.800312
# 42           0.808989           0.786517         0.791311
# 43           0.808989           0.820225         0.795805
# 44           0.808989           0.786517         0.794694
# 45           0.808989           0.786517         0.794707
# 46           0.831461           0.808989         0.799164
# 47           0.831461           0.786517         0.798052
# 48           0.820225           0.797753         0.805918
# 49           0.808989           0.786517         0.804794
# 50           0.820225           0.808989         0.804831
# 51           0.808989           0.808989         0.799238
# 52           0.842697           0.808989         0.807054
# 53           0.842697           0.808989         0.807054

# %%
titanic_test = pd.read_csv(os.path.join(dir, "test.csv"))
print(titanic_test.shape)
titanic_test.head()
# Out:
# (418, 11)
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
X_test = titanic_test
titanic_test['Survived'] = clf.predict(X_test)
titanic_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         0
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         0

# %%
titanic_test.to_csv(os.path.join(dir, "submission1.csv"), columns=["PassengerId", "Survived"], index=False)

# %%
import joblib

# %%
#persist model using joblib
objects = {
    'clf':clf
}
joblib.dump(objects, os.path.join(dir, "titanic_v2.pkl"))
# Out:
# ['C:/Users/pc/Downloads/ai-level1/titanic\\titanic_v2.pkl']
